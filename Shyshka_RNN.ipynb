# %%
def f(x):
  return np.sin(x + 3) / 2

# %%
N = 10000
data = f(np.linspace(0, 10 * np.pi, N)) + 0.1 * np.random.randn(N)

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
  tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, activation='tanh')),
  tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse', run_eagerly=True)

# %%
data = data[:, None, None]

model.fit(data, data, epochs=10)

tf.keras.backend.clear_session()

model = Sequential()
# Out:
# Epoch 1/10
# 313/313 [==============================] - 17s 53ms/step - loss: 0.0186
# Epoch 2/10
# 313/313 [==============================] - 17s 54ms/step - loss: 5.8430e-07
# Epoch 3/10
# 313/313 [==============================] - 17s 53ms/step - loss: 4.3702e-07
# Epoch 4/10
# 313/313 [==============================] - 17s 54ms/step - loss: 4.3681e-07
# Epoch 5/10
# 313/313 [==============================] - 17s 55ms/step - loss: 4.3621e-07
# Epoch 6/10
# 313/313 [==============================] - 17s 54ms/step - loss: 4.3660e-07
# Epoch 7/10
# 313/313 [==============================] - 18s 56ms/step - loss: 4.3482e-07
# Epoch 8/10
# 313/313 [==============================] - 17s 54ms/step - loss: 4.4278e-07
# Epoch 9/10
# 313/313 [==============================] - 17s 54ms/step - loss: 4.4781e-07
# Epoch 10/10
# 313/313 [==============================] - 17s 56ms/step - loss: 4.4805e-07

# %%
predictions = np.squeeze(predictions)

x_values = np.arange(0, 10 * np.pi, 10 * np.pi / N)

plt.plot(x_values, data.squeeze(), label='З шумом')
plt.plot(x_values, predictions, label='Прогноз')
plt.legend()
plt.show()
